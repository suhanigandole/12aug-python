# %% [markdown]
# # task 1
# # A student passes only if marks are 40 or more AND attendance is 75% or more.

# %%
# marks 
marks = int(input("Enter the marks"))
# attendance
attendance = int(input("enter the attendance = "))
if marks >=40 and  attendance >= 75:
        print("A student pass")
else:
        print("A student fail")
# Out:
# A student pass

# %% [markdown]
# # task 2
# ## The user can log in if the username is correct AND password is correct.

# %%
username = input("Enter the username: ")
password = input("Enter the password: ")

if username == "Suhani" and password == "12345":
    print("Login Successful")

elif username != "Suhani" and password == "12345":
    print("Username Invalid")

elif username == "Suhani" and password != "12345":
    print("Password Incorrect")

else:
    print("Username and Password are Incorrect")
# Out:
# Username and Password are Incorrect
